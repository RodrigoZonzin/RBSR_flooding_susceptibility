# %%
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import rasterio as rio
from rasterio.plot import show
import richdem as rd
from matplotlib.colors import ListedColormap

# %%
values_list = [1, 2, 3, 4, 5, 6]
colors_list = ['#006400', '#BBFCAC', '#FFFFB2', '#EA9999', '#aa0000', '#0000FF']
cmap = ListedColormap(colors_list, name='custom_cmap', N=len(colors_list))

# %%
bq_lulc = rio.open('../../dados/barbacena_2019.tif').read().astype(float)

# %%
bq_lulc = np.squeeze(bq_lulc)
bq_lulc[bq_lulc == 0] = np.nan

# %%
plt.imshow(bq_lulc, cmap = cmap)
cbar = plt.colorbar(shrink=0.5)
cbar.set_label('class', loc = 'bottom')
plt.title("Land Use and Land Cover of Barbacena - MG", loc='right')
plt.axis('off')
plt.savefig("../imgs/class_bq.png")
plt.show()
